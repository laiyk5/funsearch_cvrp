# %% [markdown]
# # FunSearch for CVRP: Sample-Efficient Heuristic Generation
#
# This notebook implements a Sample-Efficient FunSearch approach for solving the Capacitated Vehicle Routing Problem (CVRP).
#
# ## Project Overview
#
# **Task**: Automatically generate and optimize heuristic algorithms for CVRP using Large Language Models (LLMs).
#
# **Key Features**:
# - LLM-driven heuristic generation (GPT-4, Qwen, etc.)
# - Sample-efficient search with early pruning
# - Functional equivalence detection to avoid redundant evaluations
# - Multi-scale evaluation (small/medium/large instances)
#
# **Team Members**:
# - QIN YUANCHENG (59061061)
# - QIN ZIHENG (59866035)
# - LAI YIKAI (59563061)
